# %%
import pandas as pd
data = pd.read_csv("Shaft_Translation.csv")
data
# Out:
#       Count      X       Y         Z
# 0         1   0.00    0.25  0.001680
# 1         2  55.50   -7.50  0.000000
# 2         3  66.25  199.75  0.035591
# 3         4  -2.50    1.50 -0.004540
# 4         5  -2.25    2.00 -0.005342
# ...     ...    ...     ...       ...
# 1104   1105   0.25    1.00  0.001010
# 1105   1106   0.00    0.75  0.002204
# 1106   1107   0.25    0.75  0.000102
# 1107   1108   0.25    0.25 -0.000102
# 1108   1109  -0.25    0.75  0.000102
#
# [1109 rows x 4 columns]

# %%
x = 0
y = 0
z = 0
df = pd.DataFrame(data)
for i in df.index:
  x += df["X"][i]
  y += df["Y"][i]
  z += df["Z"][i]

print(x,y,z)
# Out:
# -5751.0 5897.75 nan

# %%
import pandas as pd

data = pd.read_csv("Shaft_Motion_c.csv")
data
# Out:
#       Count      X       Y         Z  Roll   Pitch   Yaw
# 0         1   0.00    0.25  0.001680 -23.74  -2.15  3.04
# 1         2  55.50   -7.50  0.000000   0.00   0.00  0.00
# 2         3  66.25  199.75  0.035591  19.67  -0.91 -0.68
# 3         4  -2.50    1.50 -0.004540  15.49  -3.62 -3.80
# 4         5  -2.25    2.00 -0.005342  14.67  -6.69 -0.65
# ...     ...    ...     ...       ...    ...    ...   ...
# 1161   1162    NaN     NaN       NaN  51.37   0.00  0.00
# 1162   1163    NaN     NaN       NaN   9.86   0.00  0.00
# 1163   1164    NaN     NaN       NaN   9.72   0.00  0.00
# 1164   1165    NaN     NaN       NaN   9.58   0.00  0.00
# 1165   1166    NaN     NaN       NaN   9.39   0.00  0.00
#
# [1166 rows x 7 columns]

# %%
t_data = pd.read_excel("Shaft_Translation.xlsx")
t_data
# Out:
#       Count      X       Y         Z
# 0         1   0.00    0.25  0.001680
# 1         2  55.50   -7.50  0.000000
# 2         3  66.25  199.75  0.035591
# 3         4  -2.50    1.50 -0.004540
# 4         5  -2.25    2.00 -0.005342
# ...     ...    ...     ...       ...
# 1104   1105   0.25    1.00  0.001010
# 1105   1106   0.00    0.75  0.002204
# 1106   1107   0.25    0.75  0.000102
# 1107   1108   0.25    0.25 -0.000102
# 1108   1109  -0.25    0.75  0.000102
#
# [1109 rows x 4 columns]

# %%
df_t = pd.DataFrame(t_data)

# %%
import matplotlib.pyplot as plt
import numpy as np


df_t.plot(kind='scatter',x='Count',y='X',color='red')
mymodel = np.poly1d(np.polyfit(df_t['Count'],df_t['X'],3))
myline = np.linspace(1, 2200, 10000)
plt.plot(myline,mymodel(myline))
plt.title("Variation of X with time")
plt.show()

# %%
df_t.plot(kind='scatter',x='Count',y='Y',color='red')
plt.title("Variation of Y with time")
plt.show()

# %%
df_t.plot(kind='scatter',x='Count',y='Z',color='red')
plt.title("Variation of Z with time")
plt.show()

# %%
for (colname,colval) in df_t.iteritems():
    print(colname, colval.values)
# Out:
# Count [   1    2    3 ... 1107 1108 1109]
# X [ 0.   55.5  66.25 ...  0.25  0.25 -0.25]
# Y [  0.25  -7.5  199.75 ...   0.75   0.25   0.75]
# Z [ 0.00168049  0.          0.03559056 ...  0.0001024  -0.00010247
#   0.0001024 ]
